# %% [markdown]
# # Neural Style Transfer (FastAPI) on Colab T4 GPU
# Run the cells below to clone the repo, install requirements, and expose the UI via LocalTunnel.

# %%
# !git clone https://github.com/Peedobus01/Neural-Style-Transfer-Platform.git
# %cd Neural-Style-Transfer-Platform
# !pip install -r requirements.txt
# !npm install -g localtunnel

# %%
import urllib.request
print("Password for LocalTunnel:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())

# !uvicorn app.backend.main:app --port 8000 & lt --port 8000
